# %%
#Import library yang dibutuhkan
from statsmodels.graphics.mosaicplot import mosaic
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mofdac/-materi-das/main/03.%20Statistika%20Terapan/boston.csv')
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# |Variable|Description|
# |--- |--- |
# |CRIM|Per capita crime rate by town|
# |ZN|Proportion of residential land zoned for lots over 25,000 sq.ft.|
# |INDUS|Proportion of non-retail business acres per town|
# |CHAS|Charles River dummy variable (1 if tract bounds river; 0 otherwise)|
# |NOX|Nitric oxides concentration (parts per 10 million)|
# |RM|Average number of rooms per dwelling|
# |AGE|Proportion of owner-occupied units built before 1940|
# |DIS|Weighted distances to five Boston employment centers|
# |RAD|Index of accessibility to radial highways|
# |TAX|Full-value property-tax rate (per 10,000 USD)|
# |PTRATIO|Pupil-teacher ratio by town|
# |BLACK|A derived feature, calculated as 1000 * (Bk - 0.63)^2 where Bk is the proportion of Black residents by town|
# |LSTAT|Percentage of lower status population|
# |MEDV|Median value of owner-occupied homes in $1000s|

# %% [markdown]
# # Soal 1

# %% [markdown]
# > Tunjukkan statisik deskriptif dari data ini (mean, media, modus dsb.) dan juga gambaran datanya secara umum. Apa interpretasi yang dapat rekan-rekan sampaikan?

# %%
#Jawaban

# %% [markdown]
# > Tunjukkan apakah terdapat outlier dari masing-masing kolom datanya? Gunakan bantuan metode IQR. Apa yang dapat rekan-rekan interpretasikan dari hasilnya?

# %%
#Jawaban

# %% [markdown]
# # Soal 2

# %% [markdown]
#  > Visualisasikan hubungan antar variabel berikut dengan scatter plot
# - MEDV dengan RM
# - MEDV dengan CRIM
# - MEDV dengan DIS
#
# Apa yang dapat rekan-rekan interpretasikan?

# %%
#Jawaban

# %% [markdown]
# > Buatlah box plot dari seluruh kolom data yang ada, jelaskan dengan pendapat rekan-rekan terkait hasilnya

# %%
#Jawaban

# %% [markdown]
# > Buatlah visualisasi dari skewness dan kurtosis data dari kolom MEDV, RM, CRIM, dan DIS. Apa yang dapat rekan-rekan interpretasikan? Transformasi dengan log jika dibutuhkan.

# %%
#Jawaban

# %% [markdown]
# # Soal 3

# %% [markdown]
# > Buatlah analisis korelasi dari kolom-kolom numerik yang ada. Apa yang dapat rekan-rekan simpulkan?

# %%
#Jawaban
