# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Understanding:-Analisis-Data-Eksploratif" data-toc-modified-id="Data-Understanding:-Analisis-Data-Eksploratif-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Data Understanding: Analisis Data Eksploratif</strong></a></span><ul class="toc-item"><li><span><a href="#Definisi" data-toc-modified-id="Definisi-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Definisi</a></span></li><li><span><a href="#Tujuan-EDA-2" data-toc-modified-id="Tujuan-EDA-2-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Tujuan EDA <a href="http://www.mat.ufrgs.br/~viali/estatistica/mat2274/material/textos/2237638.pdf" rel="nofollow" target="_blank">2</a></a></span></li></ul></li><li><span><a href="#Kerangka-Proses-EDA" data-toc-modified-id="Kerangka-Proses-EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Kerangka Proses EDA</a></span></li><li><span><a href="#EDA-dengan-Dataset-Titanic" data-toc-modified-id="EDA-dengan-Dataset-Titanic-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA dengan Dataset Titanic</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Tujuan" data-toc-modified-id="Tujuan-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Tujuan</a></span></li></ul></li></ul></li><li><span><a href="#Persiapan" data-toc-modified-id="Persiapan-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Persiapan</a></span><ul class="toc-item"><li><span><a href="#Membaca-data" data-toc-modified-id="Membaca-data-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Membaca data</a></span></li><li><span><a href="#Pandas-Review" data-toc-modified-id="Pandas-Review-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Pandas Review</a></span></li></ul></li><li><span><a href="#Jelajahi-Atribut" data-toc-modified-id="Jelajahi-Atribut-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Jelajahi Atribut</a></span><ul class="toc-item"><li><span><a href="#1.-Periksa-karakteristik-data" data-toc-modified-id="1.-Periksa-karakteristik-data-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>1. Periksa karakteristik data</a></span></li><li><span><a href="#2.-Analisis-Data-Anomali" data-toc-modified-id="2.-Analisis-Data-Anomali-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>2. Analisis Data Anomali</a></span><ul class="toc-item"><li><span><a href="#a.-Data-yang-tidak-komplit-(missing-value)" data-toc-modified-id="a.-Data-yang-tidak-komplit-(missing-value)-3.2.2.1"><span class="toc-item-num">3.2.2.1&nbsp;&nbsp;</span>a. Data yang tidak komplit (<em>missing value</em>)</a></span></li><li><span><a href="#b.-Data-duplikat" data-toc-modified-id="b.-Data-duplikat-3.2.2.2"><span class="toc-item-num">3.2.2.2&nbsp;&nbsp;</span>b. Data duplikat</a></span></li><li><span><a href="#c.-Ringkasan-statistik-(summary-statistics)" data-toc-modified-id="c.-Ringkasan-statistik-(summary-statistics)-3.2.2.3"><span class="toc-item-num">3.2.2.3&nbsp;&nbsp;</span>c. Ringkasan statistik (<em>summary statistics</em>)</a></span></li></ul></li></ul></li><li><span><a href="#Latihan" data-toc-modified-id="Latihan-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Latihan</a></span></li><li><span><a href="#Eksplorasi" data-toc-modified-id="Eksplorasi-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Eksplorasi</a></span><ul class="toc-item"><li><span><a href="#1.-Korelasi" data-toc-modified-id="1.-Korelasi-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>1. Korelasi</a></span><ul class="toc-item"><li><span><a href="#a.-Multivariat" data-toc-modified-id="a.-Multivariat-3.4.1.1"><span class="toc-item-num">3.4.1.1&nbsp;&nbsp;</span>a. Multivariat</a></span></li><li><span><a href="#b.-Bivariat" data-toc-modified-id="b.-Bivariat-3.4.1.2"><span class="toc-item-num">3.4.1.2&nbsp;&nbsp;</span>b. Bivariat</a></span></li></ul></li><li><span><a href="#2.-Visualisasi" data-toc-modified-id="2.-Visualisasi-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>2. Visualisasi</a></span><ul class="toc-item"><li><span><a href="#a.-Data-Univariat-diskrit/kategorik" data-toc-modified-id="a.-Data-Univariat-diskrit/kategorik-3.4.2.1"><span class="toc-item-num">3.4.2.1&nbsp;&nbsp;</span>a. Data Univariat diskrit/kategorik</a></span></li><li><span><a href="#b.-Data-Univariat-kontinu" data-toc-modified-id="b.-Data-Univariat-kontinu-3.4.2.2"><span class="toc-item-num">3.4.2.2&nbsp;&nbsp;</span>b. Data Univariat kontinu</a></span></li><li><span><a href="#c.-Pencilan-(outlier)" data-toc-modified-id="c.-Pencilan-(outlier)-3.4.2.3"><span class="toc-item-num">3.4.2.3&nbsp;&nbsp;</span>c. Pencilan (<em>outlier</em>)</a></span></li><li><span><a href="#d.-Data-Bivariat" data-toc-modified-id="d.-Data-Bivariat-3.4.2.4"><span class="toc-item-num">3.4.2.4&nbsp;&nbsp;</span>d. Data Bivariat</a></span></li></ul></li><li><span><a href="#3.-Uji-Asumsi" data-toc-modified-id="3.-Uji-Asumsi-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>3. Uji Asumsi</a></span><ul class="toc-item"><li><span><a href="#a.-Normalitas-Variabel-diskrit/kategorik" data-toc-modified-id="a.-Normalitas-Variabel-diskrit/kategorik-3.4.3.1"><span class="toc-item-num">3.4.3.1&nbsp;&nbsp;</span>a. Normalitas Variabel diskrit/kategorik</a></span></li><li><span><a href="#a.-Normalitas-Variabel-kontinu" data-toc-modified-id="a.-Normalitas-Variabel-kontinu-3.4.3.2"><span class="toc-item-num">3.4.3.2&nbsp;&nbsp;</span>a. Normalitas Variabel kontinu</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Tambahan:-Pandas-Support-Libraries" data-toc-modified-id="Tambahan:-Pandas-Support-Libraries-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Tambahan: Pandas Support Libraries</a></span></li><li><span><a href="#Tugas-Asynchronous:-Melakukan-Analisis-Data-Eksploratif" data-toc-modified-id="Tugas-Asynchronous:-Melakukan-Analisis-Data-Eksploratif-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Tugas Asynchronous: Melakukan Analisis Data Eksploratif</a></span></li></ul></div>

# %% [markdown]
# # **Data Understanding: Analisis Data Eksploratif**
#
#
# Tanggal : 11 Februari 2026
#
# oleh:<br>
# __Ibnu Pujiono__
#
# _Ministry of Finance Data Analytics Community (MoF-DAC)_
#
#
#
# ---

# %% [markdown]
# ## Definisi
# > Proses Analisis Data Eksploratif (*Exploratory Data Analysis*/EDA) adalah suatu usaha untuk memahami data dengan melakukan penyelidikan awal untuk:
# *   Menemukan pola,
# *   Mencari anomali,
# *   Mengetes asumsi, dan
# *   Menguji hipotesis
#
# > Dengan menggunakan *visualisasi data* dan *ringkasan statistik* [1](https://towardsdatascience.com/exploratory-data-analysis-8fc1cb20fd15)

# %% [markdown]
# > EDA adalah bagian dari *Data Understanding* dari kerangka "CRISP-DM".
#
# ![Crisp-DM.png](data:image/png;base64,...)

# %% [markdown]
# ## Tujuan EDA [2](http://www.mat.ufrgs.br/~viali/estatistica/mat2274/material/textos/2237638.pdf)
# 1. Menarik hipotesis tentang penyebab fenomena yang diamati
# 2. Menilai asumsi yang menjadi dasar inferensi statistik
# 3. Mendukung pemilihan teknik statistik yang tepat
# 4. Memberikan dasar untuk pengumpulan data lebih lanjut

# %% [markdown]
# # Kerangka Proses EDA

# %% [markdown]
# > Proses EDA dapat diilustrasikan dalam langkah-langkah sebagai berikut[3](https://www.researchgate.net/publication/329930775_A_comprehensive_review_of_tools_for_exploratory_analysis_of_tabular_industrial_datasets) :
#
# ![The-fundamental-steps-of-the-exploratory-data-analysis-process.png](data:image/png;base64,...)

# %% [markdown]
# # EDA dengan Dataset Titanic
#
# Dataset Titanic berisi data rincian penumpang Kapal Titanic yang tenggelam secara tragis pada tahun 1912.[4](https://www.kaggle.com/c/titanic/data)
#
# #### Tujuan
# 1. Memahami hubungan antara rincian data dari penumpang yang selamat dan penumpang yang tidak selamat
# 2. Melakukan prediksi selamat/tidak selamat berdasarkan rincian data penumpang

# %% [markdown]
# ## Persiapan

# %% [markdown]
# > *   Install dan import pandas
# > *   Import dataset "Titanic" dan simpan dalam dataframe "data"

# %% [markdown]
# ### Membaca data

# %%
link_titanic = "https://raw.githubusercontent.com/mofdac/-materi-das/main/01.%20Python%20for%20DA/titanic.csv"

#pip install pandas #ini diperlukan apabila berlum terinstall pandas
import pandas as pd
data = pd.read_csv(link_titanic) #menyimpan dataset titanic dalam dataframe bernama 'data'
data.head() #mempelihatkan 5 isian awal dan akhir dari 'data'
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# |Variable|Description|
# |--- |--- |
# |PassengerId|Id of passenger|
# |Survived|Survival (0 = No; 1 = Yes)|
# |Pclass|Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)|
# |Name|Name|
# |Sex|Sex|
# |Age|Age|
# |SibSp|Number of Siblings/Spouses Aboard|
# |Parch|Number of Parents/Children Aboard|
# |Ticket|Ticket Number|
# |Fare|Passenger Fare (British pound)|
# |Cabin|Cabin|
# |Embarked|Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)|

# %% [markdown]
# ### Pandas Review

# %% [markdown]
# > Mengakses kolom

# %%
# using '.'
#data.Fare
# or using []
#data['Pclass']
# using extra `[]` <- untuk lebih dari satu kolom
data[['Age','Pclass']]
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %% [markdown]
# > Mengakses baris

# %%
## filter rows with index number
data.iloc[2:10,]
# or
#data.loc[0:10:3,]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# > Menggunakan loc dengan nama kolom

# %%
#data.loc[0:10, 'Cabin']
#data.loc[0:10,'PassengerId':'Cabin']
data.loc[0:10,['PassengerId','Name','Cabin']]
# Out:
#     PassengerId                                               Name Cabin
# 0             1                            Braund, Mr. Owen Harris   NaN
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...   C85
# 2             3                             Heikkinen, Miss. Laina   NaN
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# 4             5                           Allen, Mr. William Henry   NaN
# 5             6                                   Moran, Mr. James   NaN
# 6             7                            McCarthy, Mr. Timothy J   E46
# 7             8                     Palsson, Master. Gosta Leonard   NaN
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   NaN
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)   NaN
# 10           11                    Sandstrom, Miss. Marguerite Rut    G6

# %% [markdown]
# > Menggunakan .iloc dengan nomor index

# %%
#data.iloc[0:10,0:4]
data.iloc[0:10, [0,3,2,1]]
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
# 5            6                                   Moran, Mr. James       3
# 6            7                            McCarthy, Mr. Timothy J       1
# 7            8                     Palsson, Master. Gosta Leonard       3
# 8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 9           10                Nasser, Mrs. Nicholas (Adele Achem)       2
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
# 5         0
# 6         0
# 7         0
# 8         1
# 9         1

# %% [markdown]
# > Conditional filter dan query

# %%
# conditional
#data[data.Age >20] #akses data penumpang yang umurnya diatas 10 tahun
# or use query
data.query('Age > 10')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Filter data berdasarkan kriteria
data[data.Sex == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# > Sorting data

# %%
## Sorting Data

# sort based on column
#data.sort_values('Age', ascending = False)

#two or more col
data.sort_values(['Age','Pclass', 'Sex'], ascending = (True,False,True))
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# ..           ...       ...     ...                              ...     ...
# 740          741         1       1      Hawksford, Mr. Walter James    male
# 766          767         0       1        Brewe, Dr. Arthur Jackson    male
# 793          794         0       1         Hoyt, Mr. William Fisher    male
# 815          816         0       1                 Fry, Mr. Richard    male
# 839          840         1       1             Marechal, Mr. Pierre    male
#
# ...

# %% [markdown]
# > Grouping

# %%
# Kelompokan berdasarkan embark_town
data_grouped = data.groupby(['Embarked']).sum('Fare')
data_grouped
# Aggregate functions: count(), mean(), sum(), min(), max(), median(), quantile(), var(), std()
# Out:
#           PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Embarked
# C               74820        93     317   4005.92     65     61  10072.2962
# Q               32178        30     224    786.50     33     13   1022.2543
# S              289496       217    1514  16312.75    368    266  17439.3988

# %%
# Melihat value pada group embark_town
#data.groupby(['Embarked']).get_group('Q')
grp = data.groupby("Embarked")
grp['Fare'].mean() #rata-rata Fare dari hasil groupby
#grp.get_group("Q")
# Out:
# Embarked
# C    59.954144
# Q    13.276030
# S    27.079812
# Name: Fare, dtype: float64

# %%
# help?
data.groupby?

# %% [markdown]
# ## Jelajahi Atribut

# %% [markdown]
# ### 1. Periksa karakteristik data

# %%
data.shape #'bentuk'/dimensi data: jumlah baris, jumlah kolom
# Out:
# (891, 12)

# %%
data.index #jumlah index dalam data
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
data.dtypes #tipe data per kolom
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.columns #kolom-kolom
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.size #ukuran data (jumlah record)
# Out:
# 10692

# %%
data.info() #informasi data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head(10) #atau data.tail() dan data.sample() ==> intip sebagian porsi dari data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 648          649         0       3
# 741          742         0       1
# 513          514         1       1
# 715          716         0       3
# 694          695         0       1
#
#                                                Name     Sex   Age  SibSp  \
# 648                              Willey, Mr. Edward    male   NaN      0
# 741                   Cavendish, Mr. Tyrell William    male  36.0      1
# 513  Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 715      Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0      0
# 694                                 Weir, Col. John    male  60.0      0
#
#      Parch         Ticket   Fare  Cabin Embarked
# 648      0  S.O./P.P. 751   7.55    NaN        S
# 741      0          19877  78.85    C46        S
# 513      0       PC 17603  59.40    NaN        C
# 715      0         348124   7.65  F G73        S
# 694      0         113800  26.55    NaN        S

# %%
#mengambil data numerik
num_cols = data._get_numeric_data().columns
print(num_cols)
titanic_numeric = data[num_cols]
titanic_numeric.head()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
#mengambil data non_numeric
titanic_non_numeric = data.drop(num_cols, axis = 1)
titanic_non_numeric.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %% [markdown]
# ### 2. Analisis Data Anomali

# %% [markdown]
# #### a. Data yang tidak komplit (*missing value*)

# %%
# Menjumlahkan isian kosong per kolom
data.isnull().sum()
#atau
#data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Mencari data N/A per baris dan per kolom
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# #### b. Data duplikat

# %%
# per baris (row) data
data.duplicated().sum()
# Out:
# 0

# %%
data.loc[0:10].duplicated().sum()
# Out:
# 0

# %%
# per kolom (column) data
data['Ticket'].duplicated().sum() #misal di kolom "Ticket"
# Out:
# 210

# %% [markdown]
# #### c. Ringkasan statistik (*summary statistics*)

# %%
#Unique value per kolom
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
#Jumlah unique value per kolom
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data.describe() #ringkasan statistik data numerik
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include=['O']) #ringkasan statistik data nonnumerik
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# <details>
# Kesimpulan sementara:
#
# 1. *Kelengkapan Data*.
#    Perlu dilakukan penanganan atas record *null* pada:
#     * 'Age'
#     * 'Embarked'
#     * 'Cabin'
# 3. *Keakuratan*.
#    Karena tujuan bisnis telah diketahui (mencari tahu rincian data penumpang selamat), maka dapat disusun komentar atas kolom-kolom berikut:
#     * 'PassengerId' dapat dikeluarkan karena secara logika berkemungkinan tidak berkontribusi pada selamatnya penumpang ('Survived').
#     * 'Ticket' terdapat duplikasi cukup banyak dan kemungkinan tidak berkontribusi pada 'Survived'.
#     * 'Cabin' terlalu banyak "null values", namun mungkin berkorelasi dengan 'Survived'
#     * 'Name' unik dan tidak standar, namun tidak memiliki "null values" dan terdapat titel standar. Titel ini kemungkinan berkorelasi dengan 'Survived'
# </details>

# %% [markdown]
# ## Latihan

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/mofdac/-materi-das/main/02.%20Data%20and%20Business%20Understanding/tugas/diamonds.csv')
df = df.drop('Unnamed: 0',axis=1)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Columns Metadata:
#
# carat: berat diamond
#
# cut: kualitas diamond
#
# color: warna diamond
#
# clarity: level kemurnian diamonds
#
# depth: tinggi dari diamond tabel
#
# table: lebar  dari diamond tabel
#
# price: harga diamond ($US)
#
# x: panjang
#
# y: lebar
#
# z: kedalaman

# %% [markdown]
# **Latihan Bagian 1** <br>
# Lakukan groupby pada data berdasarkan kriteria cut(kualitas) dan color (warna) secara berurutan kemudian aggregasi objek group by nya dengan fungsi median.
#
# Kemudian Jawab Pertanyaan berikut:
#
# > Berapa nilai median dari harga diamond berkualitas good dan berwarna F

# %%
#jawaban

# %% [markdown]
# > Ada berapa jenis warna (color) dan clarity dari diamond di dalam data ini?

# %%
#jawaban

# %% [markdown]
# > Apa jenis potongan (cut) dan level kemurnian (clarity) dari berlian yang paling mahal dan paling murah?

# %%
#jawaban

# %% [markdown]
# Berapa rata-rata harga dan "carat" dari diamond berkualitas "Premium"?

# %%
#jawaban

# %% [markdown]
# **Latihan Bagian 2** <br>
# Dari data Titanic sebelumnya, coba jawab pertanyaan ini :

# %%
# 1. berapa rata2 umur orang yang jenis kelaminnya laki2?

# 2. median harga tiket jenis kelamin perempuan?

# %% [markdown]
# ## Eksplorasi

# %% [markdown]
# ### 1. Korelasi

# %% [markdown]
# #### a. Multivariat

# %%
# Hubungan antarsemua variabel numerik
titanic_numeric.corr().sort_values(by='Survived')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
#
#                  Fare
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# PassengerId  0.012658
# Parch        0.216225
# Fare         1.000000
# Survived     0.257307

# %% [markdown]
# - Dari sini kita dapat melihat "Kekuatan" dari tiap-tiap variabel untuk memengaruhi nilai Survived
# - Untuk melihat bagaimana masing-masing variabel dapat berkaitan, kita dapat menggunakan correlation matrix yang ditampilkan sebagai heatmap

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.heatmap(titanic_numeric.corr(),annot=True)
plt.show()

# %% [markdown]
# #### b. Bivariat

# %%
# Hubungan 'Sex' dan 'Survived'
data_ct_sex = pd.crosstab(data['Sex'], data['Survived'],margins=True)
data_ct_sex.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_7aa5f_row0_col0, #T_7aa5f_row0_col2, #T_7aa5f_row1_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_7aa5f_row0_col1 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_7aa5f_row1_col0 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_7aa5f_row1_col2 {
#   background-color: #74ba66;
#   color: #f1f1f1;
# }
# #T_7aa5f_row2_col0, #T_7aa5f_row2_col1, #T_7aa5f_row2_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_7aa5f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_7aa5f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7aa5f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7aa5f_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# Hubungan 'PClass' dan 'Survived'
data_ct_pclass = pd.crosstab(data['Pclass'], data['Survived'],margins=True)
data_ct_pclass.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_2d1a2_row0_col0, #T_2d1a2_row1_col1, #T_2d1a2_row1_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_2d1a2_row0_col1 {
#   background-color: #319866;
#   color: #f1f1f1;
# }
# #T_2d1a2_row0_col2 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_2d1a2_row1_col0 {
#   background-color: #098466;
#   color: #f1f1f1;
# }
# #T_2d1a2_row2_col0 {
#   background-color: #9fcf66;
#   color: #000000;
# }
# #T_2d1a2_row2_col1 {
#   background-color: #209066;
#   color: #f1f1f1;
# }
# #T_2d1a2_row2_col2 {
#   background-color: #6fb766;
#   color: #f1f1f1;
# }
# #T_2d1a2_row3_col0, #T_2d1a2_row3_col1, #T_2d1a2_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_2d1a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_2d1a2_level0_col0" class="col_heading level0 col0" >0</th>
# ...

# %%
# Hubungan 'Embarked' dan 'Survived'
data_ct_embarked = pd.crosstab(data['Embarked'], data['Survived'],margins=True)
data_ct_embarked.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_60c90_row0_col0 {
#   background-color: #0e8666;
#   color: #f1f1f1;
# }
# #T_60c90_row0_col1 {
#   background-color: #349a66;
#   color: #f1f1f1;
# }
# #T_60c90_row0_col2 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_60c90_row1_col0, #T_60c90_row1_col1, #T_60c90_row1_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_60c90_row2_col0 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_60c90_row2_col1 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_60c90_row2_col2 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_60c90_row3_col0, #T_60c90_row3_col1, #T_60c90_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_60c90" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_60c90_level0_col0" class="col_heading level0 col0" >0</th>
# ...

# %%
# Hubungan 'Sibsp' dan 'Survived'
data_ct_sibsp = pd.crosstab(data['SibSp'], data['Survived'],margins=True)
data_ct_sibsp.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_00e55_row0_col0 {
#   background-color: #b8dc66;
#   color: #000000;
# }
# #T_00e55_row0_col1 {
#   background-color: #9dce66;
#   color: #000000;
# }
# #T_00e55_row0_col2 {
#   background-color: #aed666;
#   color: #000000;
# }
# #T_00e55_row1_col0 {
#   background-color: #2b9566;
#   color: #f1f1f1;
# }
# #T_00e55_row1_col1 {
#   background-color: #53a966;
#   color: #f1f1f1;
# }
# #T_00e55_row1_col2 {
#   background-color: #3a9c66;
#   color: #f1f1f1;
# }
# #T_00e55_row2_col0, #T_00e55_row4_col0 {
#   background-color: #048266;
#   color: #f1f1f1;
# }
# #T_00e55_row2_col1 {
#   background-color: #098466;
#   color: #f1f1f1;
# }
# #T_00e55_row2_col2 {
#   background-color: #068266;
#   color: #f1f1f1;
# }
# #T_00e55_row3_col0, #T_00e55_row3_col2, #T_00e55_row4_col2 {
#   background-color: #038166;
#   color: #f1f1f1;
# }
# #T_00e55_row3_col1, #T_00e55_row4_col1 {
#   background-color: #028066;
#   color: #f1f1f1;
# }
# ...

# %%
# Hubungan 'Parch' dan 'Survived'
data_ct_parch = pd.crosstab(data['Parch'], data['Survived'],margins=True)
data_ct_parch.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8883d_row0_col0 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_8883d_row0_col1 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_8883d_row0_col2 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_8883d_row1_col0 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_8883d_row1_col1 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_8883d_row1_col2 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_8883d_row2_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_8883d_row2_col1 {
#   background-color: #e2f066;
#   color: #000000;
# }
# #T_8883d_row2_col2 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_8883d_row3_col0, #T_8883d_row4_col1, #T_8883d_row4_col2, #T_8883d_row5_col1, #T_8883d_row6_col0, #T_8883d_row6_col1, #T_8883d_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_8883d_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# ...

# %% [markdown]
# ### 2. Visualisasi

# %% [markdown]
# **Mengapa menggunakan Visualisasi?**
# ![viz.png](data:image/png;base64,...)
#
# **Descriptive statistics might be wrong!**
#
# source:https://www.autodesk.com/research/publications/same-stats-different-graphs

# %% [markdown]
# #### a. Data Univariat diskrit/kategorik

# %%
# Kolom 'Survived', 'Sex', dan 'Pclass'

f,ax=plt.subplots(1,3,figsize=(15,4))

# subplot 1
data['Survived'].value_counts().sort_index().plot.bar(color=['blue','green'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Survived')
ax[0].set_ylabel('Count')


# subplot 2
data['Sex'].value_counts().sort_index().plot.bar(color=['blue','green'],ax=ax[1])
ax[1].set_title('Number Of Passengers By Sex')
ax[1].set_ylabel('Count')

# subplot 3
data['Pclass'].value_counts().sort_index().plot.bar(color=['blue','green','red'],ax=ax[2])
ax[2].set_title('Number Of Passengers By Pclass')
ax[2].set_ylabel('Count')

# show
plt.show()

# %%
# Kolom 'Embarked', 'Sibsp', dan 'Parch'


f,ax=plt.subplots(1,3,figsize=(15,4))

# subplot 1
data['Embarked'].value_counts().sort_index().plot.bar(color=['blue','green','red','yellow'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Embarked')
ax[0].set_ylabel('Count')

# subplot 1
data['SibSp'].value_counts().sort_index().plot.bar(color=['blue','green'],ax=ax[1])
ax[1].set_title('Number Of Passengers By SibSp')
ax[1].set_ylabel('Count')


# subplot 2
data['Parch'].value_counts().sort_index().plot.bar(color=['blue','green'],ax=ax[2])
ax[2].set_title('Number Of Passengers By Parch')
ax[2].set_ylabel('Count')

# show
plt.show()

# %% [markdown]
# #### b. Data Univariat kontinu

# %%
# Kolom 'Age' dan 'Fare'

f,ax=plt.subplots(figsize=(10,8))

plt.subplot(2,2,1)
data.Age.plot.hist()
plt.title('Age')

plt.subplot(2,2,2)
data.Fare.plot.hist()
plt.title('Fare')
# Out:
# Text(0.5, 1.0, 'Fare')

# %% [markdown]
# #### c. Pencilan (*outlier*)

# %%
# Pencilan 'Age' dan 'Fare'
f,ax=plt.subplots(figsize=(10,8))

plt.subplot(2,2,1)
data['Age'].plot.box()
plt.title('Age')

plt.subplot(2,2,2)
data['Fare'].plot.box()
plt.title('Fare')
# Out:
# Text(0.5, 1.0, 'Fare')

# %%
# 'Fare' vs 'Age'
fig, ax = plt.subplots(figsize=(8,5))
sns.regplot(x=data['Age'], y=data['Fare'],  scatter_kws = {'s': 25}, lowess=True)
sns.despine()

# %% [markdown]
# #### d. Data Bivariat

# %%
# 'Age' vs 'Survived'
sns.swarmplot(x="Survived", y="Age", data = data, size=4)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
# 'Fare' vs 'Survived'
sns.swarmplot(x="Survived", y="Fare", data = data)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 58.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 28.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Survived', ylabel='Fare'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#'Sex' vs 'Survived', 'Pclass' vs 'Survived', dan 'Embarked' vs 'Survived'

f,ax=plt.subplots(1,3,figsize=(15,5))

# subplot 1
sns.countplot(x='Sex',hue='Survived',data=data, ax=ax[0])
ax[0].set_title('Sex')

# subplot 2
sns.countplot(x='Pclass',hue='Survived',data=data, ax=ax[1])
ax[1].set_title('Pclass')

# subplot 3
sns.countplot(x='Embarked',hue='Survived',data=data, ax=ax[2])
ax[2].set_title('Embarked')

# show
#plt.show()
# Out:
# Text(0.5, 1.0, 'Embarked')

# %%
#'Sibsp' vs 'Survived' dan 'Parch' vs 'Survived'

f,ax=plt.subplots(1,2,figsize=(15,5))

# subplot 1
sns.countplot(x='SibSp',hue='Survived',data=data, ax=ax[0])
ax[0].set_title('SibSp')

# subplot 2
sns.countplot(x='Parch',hue='Survived',data=data, ax=ax[1])
ax[1].set_title('Parch')

# show
#plt.show()
# Out:
# Text(0.5, 1.0, 'Parch')

# %%
# 'Age' vs 'Not Survived'
plt.figure(figsize=(10,5))
sns.histplot(data.Age[data.Survived == 0], color = 'red', label = 'not survive', kde=True, stat="density", linewidth=0)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# 'Age' vs 'Survived'
plt.figure(figsize=(10,5))
sns.histplot(data.Age[data.Survived == 1], color = 'green', label = 'survive', kde=True, stat="density", linewidth=0)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# 'Age' vs 'Survived' and 'NotSurvived'

plt.figure(figsize=(10,5))

sns.histplot(data.Age[data.Survived == 0], color = 'red', label = 'not survive', kde=True, stat="density", linewidth=0)
sns.histplot(data.Age[data.Survived == 1], color = 'green', label = 'survive', kde=True, stat="density", linewidth=0)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### 3. Uji Asumsi

# %% [markdown]
# #### a. Normalitas Variabel diskrit/kategorik

# %% [markdown]
# Uji Chi Square biasa digunakan untuk melihat apakah terdapat hubungan antara 2 variabel. Dengan tingkat signifikansi 5%, terdapat hubungan yang signifikan secara statistik antara kedua variabel kategorikal (p <= 0.05)

# %%
from scipy.stats import chi2_contingency

def chi_test(data):
    # defining the table
    stat, p, dof, expected = chi2_contingency(data)

    # interpret p-value
    alpha = 0.05
    print("p value is " + str(p))
    if p <= alpha:
        print('Dependent (Tolak H0)')
    else:
        print('Independent (H0 diterima)')

chi_test(data_ct_sex)
chi_test(data_ct_pclass)
chi_test(data_ct_embarked)
chi_test(data_ct_sibsp)
chi_test(data_ct_parch)
# Out:
# p value is 1.0036732821369117e-55
# Dependent (reject H0)
# p value is 6.258462423531468e-20
# Dependent (reject H0)
# p value is 0.00018045058101554055
# Dependent (reject H0)
# p value is 0.000670965497493342
# Dependent (reject H0)
# p value is 0.014554047586837713
# Dependent (reject H0)

# %% [markdown]
# #### a. Normalitas Variabel kontinu

# %%
# Age

plt.figure(figsize=(2,2))
sns.displot(data.Age, color = "green")

# %%
# Fare

plt.figure(figsize=(10,5))
sns.displot(data.Fare, color = "green")

# %% [markdown]
# <details>
# Kesimpulan sementara:
#
# > 1. jumlah penumpang 'survived' lebih sedikit daripada 'unsurvived'
# 2. jumlah penumpang 'male' lebih banyak daripada penumpang 'female'
# 3. jumlah penumpang kelas 3 lebih banyak daripada kelas lainnya
# 4. jumlah penumpang sendirian lebih banyak dari pada yang keluarga dan saudara
# 5. jumlah penumpang dengan 'Embarked' Southampton lebih banyak daripada embarked lainnya
# 6. penumpang paling banyak berkisar pada usia 20 - 40 tahun
# 7. terdapat data outlier pada fitur 'Age' dan fitur 'Fare'
# 8. data pada fitur 'Age' dan 'Fare' mempunyai sebaran data tidak normal
# 9. *Feature Enginering*. Kemungkinan modifikasi kolom untuk mencari hubungan 'Survived':
#     * 'SibSp' dapat digunakan untuk membuat kelompok, kemungkinan berkorelasi dengan 'Survived'
#     * 'Parch' dapat digunakan untuk membuat fitur keluarga, kemungkinan berkorelasi dengan 'Survived'
#     * 'Name' dapat dilakukan ekstraksi untuk mengeluarkan titel
#     * 'Age' dapat dikelompokkan menjadi ordinal kategori
#     * 'Fare' dapat dikelompokkan menjadi ordinal kategori
# 10. Dari 'Sex', 'Age', dan 'PClass' dapat dirumuskan hipotesis bahwa: Perempuan, anak-anak, orang kaya lebih mungkin untuk bertahan hidup.
# </details>

# %% [markdown]
# # Tambahan: Pandas Support Libraries
#
# **PandasGUI**
# PandasGUI is suitable for in-depth analysis with manual drag-and-drop capability.
#
# **Pandas-profilling**
# Pandas Profiling suitable for a quick analysis generation for a single variable.
#
# **SweetViz**
# Sweetviz suitable for analysis between dataset and to the target feature.

# %%
# !pip install ydata-profiling
#!pip install pandasgui
#!pip install sweetviz

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Pandas profiling
import pandas as pd
data = pd.read_csv(link_titanic) #menyimpan dataset titanic dalam dataframe bernama 'data'

from pandas_profiling import ProfileReport
prof = ProfileReport(data, title="Titanic Profiling Report")
prof.to_file(output_file='output.html')
# Out:
# /tmp/ipython-input-759452155.py:5: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Tugas Asynchronous: Melakukan Analisis Data Eksploratif
#
# **Analisis Data Eksploratif: House Price**
# Tujuan tugas adalah untuk melakukan EDA pada dataset House Price. Data memiliki 79 explanatory variables yang mendeskripsikan hampir dari semua aspek dari rumah di daerah Ames, Iowa.
# <br>
# Deskripsi Data dapat dilihat pada alamat ini : https://github.com/mofdac/-materi-das/blob/main/02.%20Data%20and%20Business%20Understanding/tugas/data_description.txt <br>
# **Cek Data**
# 1. Load data ke pandas
# 2. Cek apakah ada data yang memiliki data kosong/NaN, hitung berapa % data kosong
# 3. Identifikasi kolom yang bersifat numerik dan non numerik
# 4. Buat dan intepretasikan ringkasan statistik deskriptif
#
# **Univariate**
#
# Cek Categorical Variables
# 1. Buat barplot pada **MSZoning, Street, dan LotShape**
# 2. Jelaskan bagaimana data terdistribusi dan informasi lain yang anda dapatkan dari plot yang telah dibuat
#
# Cek Numerical Variables
# 1. Buat histogram pada **SalePrice, LotArea, 2ndFlrSF**
# 2. Jelaskan bagaimana data terdistribusi dan informasi lain yang anda dapatkan dari plot yang telah dibuat
#
# **Multivariate**
# 1. Buatlah matriks korelasi dari variabel yang bersifat numerik
#
# **Bivariate**
# 1. Buat scatterplot variabel 1stFlrSF vs SalePrice, berikan penjelasan tentang hasil yang anda dapatkan (scatterplot cukup berguna untuk menganalisis 2 variabel numerik)
# 2. Buat boxplot variabel FullBath dengan SalePrice, , berikan penjelasan tentang hasil yang anda dapatkan (boxplot cukup berguna untuk menganalisis data ordinal/kategorikal)
